# %% [markdown]
# ### Задание
#
# 1) Модифицируйте код и реализуйте [Wasserstein GAN](https://arxiv.org/abs/1701.07875) ([From GAN to WGAN
# ](https://lilianweng.github.io/posts/2017-08-20-gan/)) используя weight clipping. (1 балл)
#
# 2) Замените  weight clipping на [gradient penalty](https://arxiv.org/pdf/1704.00028v3.pdf). (1 балл)
#
# 3) Добавьте к обучению WGAN условие на метку, продемонстрируйте [условную генерацию](https://arxiv.org/pdf/1411.1784.pdf).  (1 балл)
#
# Напишите отчет о том, что попробовали, какие результаты получили, какую архитектуру использовали, как вам кажется надо обучать GAN, чтобы добиться сходимости? Каждый пункт обязательно сопроводите визуализациями.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import torchvision
import matplotlib.pyplot as plt
import numpy as np

from torch.autograd import Variable

# %%
class Config:
    pass

config = Config()
config.mnist_path = None
config.batch_size = 16
config.num_workers = 3
config.num_epochs = 10
config.noise_size = 50
config.print_freq = 100

# %%
train = torchvision.datasets.FashionMNIST("fashion_mnist", train=True, transform=torchvision.transforms.ToTensor(), download=True)

# %%
dataloader = DataLoader(train, batch_size=16, shuffle=True)

# %%
len(dataloader)
# Out:
# 3750

# %%
for image, cat in dataloader:
    break

# %%
image.size()
# Out:
# torch.Size([16, 1, 28, 28])

# %%
28*28
# Out:
# 784

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential( 
            nn.Linear(config.noise_size, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 28*28),
            nn.Sigmoid())
        
    def forward(self, x):
        return self.model(x)
    
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(28*28, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 1), 
            nn.Sigmoid())
    def forward(self, x):
        return self.model(x)

# %%
generator = Generator()
discriminator = Discriminator()

# %%
optim_G = optim.Adam(params=generator.parameters(), lr=0.0001)
optim_D = optim.Adam(params=discriminator.parameters(), lr=0.0001)

criterion = nn.BCELoss()

# %%
input = Variable(torch.FloatTensor(config.batch_size, 28*28))
noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size))
fixed_noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size).normal_(0, 1))
label = Variable(torch.FloatTensor(config.batch_size))
real_label = 1
fake_label = 0

# %%
ERRD_x = np.zeros(config.num_epochs)
ERRD_z = np.zeros(config.num_epochs)
ERRG = np.zeros(config.num_epochs)
N = len(dataloader)

for epoch in range(config.num_epochs):
    for iteration, (images, cat) in enumerate(dataloader):
        ####### 
        # Discriminator stage: maximize log(D(x)) + log(1 - D(G(z))) 
        #######
        discriminator.zero_grad()
        
        # real
        label.data.fill_(real_label)
        input_data = images.view(images.shape[0], -1)
        output = discriminator(input_data)
        errD_x = criterion(output, label.reshape(-1, 1))
        ERRD_x[epoch] += errD_x.item()
        errD_x.backward()
        
        # fake 
        noise.data.normal_(0, 1)
        fake = generator(noise)
        label.data.fill_(fake_label)
        output = discriminator(fake.detach())
        errD_z = criterion(output, label.reshape(-1, 1))
        ERRD_z[epoch] += errD_z.item()
        errD_z.backward()
        
        optim_D.step()
        
        ####### 
        # Generator stage: maximize log(D(G(x))
        #######
        generator.zero_grad()
        label.data.fill_(real_label)
        output = discriminator(fake)
        errG = criterion(output, label.reshape(-1, 1))
        ERRG[epoch] += errG.item()
        errG.backward()
        
        optim_G.step()
        
        if (iteration+1) % config.print_freq == 0:
            print('Epoch:{} Iter: {} errD_x: {:.2f} errD_z: {:.2f} errG: {:.2f}'.format(epoch+1,
                                                                                            iteration+1, 
                                                                                            errD_x.item(),
                                                                                            errD_z.item(), 
                                                                                            errG.item()))
# Out:
# Epoch:1 Iter: 100 errD_x: 0.18 errD_z: 0.12 errG: 2.31
# Epoch:1 Iter: 200 errD_x: 0.29 errD_z: 0.16 errG: 2.21
# Epoch:1 Iter: 300 errD_x: 0.33 errD_z: 0.10 errG: 2.63
# Epoch:1 Iter: 400 errD_x: 0.11 errD_z: 0.15 errG: 2.26
# Epoch:1 Iter: 500 errD_x: 0.04 errD_z: 0.10 errG: 2.51
# Epoch:1 Iter: 600 errD_x: 0.04 errD_z: 0.07 errG: 2.92
# Epoch:1 Iter: 700 errD_x: 0.02 errD_z: 0.15 errG: 2.28
# Epoch:1 Iter: 800 errD_x: 0.03 errD_z: 0.14 errG: 2.34
# Epoch:1 Iter: 900 errD_x: 0.16 errD_z: 0.13 errG: 2.40
# Epoch:1 Iter: 1000 errD_x: 0.08 errD_z: 0.20 errG: 2.12
# Epoch:1 Iter: 1100 errD_x: 0.24 errD_z: 0.12 errG: 2.31
# Epoch:1 Iter: 1200 errD_x: 0.09 errD_z: 0.14 errG: 2.26
# Epoch:1 Iter: 1300 errD_x: 0.15 errD_z: 0.11 errG: 2.83
# Epoch:1 Iter: 1400 errD_x: 0.19 errD_z: 0.15 errG: 2.16
# Epoch:1 Iter: 1500 errD_x: 0.13 errD_z: 0.23 errG: 1.90
# Epoch:1 Iter: 1600 errD_x: 0.02 errD_z: 0.36 errG: 1.78
# Epoch:1 Iter: 1700 errD_x: 0.22 errD_z: 0.15 errG: 2.50
# Epoch:1 Iter: 1800 errD_x: 0.19 errD_z: 0.17 errG: 2.25
# Epoch:1 Iter: 1900 errD_x: 0.13 errD_z: 0.38 errG: 1.57
# Epoch:1 Iter: 2000 errD_x: 0.44 errD_z: 0.11 errG: 2.64
# Epoch:1 Iter: 2100 errD_x: 0.14 errD_z: 0.09 errG: 2.88
# Epoch:1 Iter: 2200 errD_x: 0.06 errD_z: 0.09 errG: 3.07
# Epoch:1 Iter: 2300 errD_x: 0.02 errD_z: 0.24 errG: 2.70
# Epoch:1 Iter: 2400 errD_x: 0.18 errD_z: 0.08 errG: 3.60
# Epoch:1 Iter: 2500 errD_x: 0.01 errD_z: 0.16 errG: 2.85
# Epoch:1 Iter: 2600 errD_x: 0.10 errD_z: 0.11 errG: 2.92
# Epoch:1 Iter: 2700 errD_x: 0.10 errD_z: 0.06 errG: 3.45
# Epoch:1 Iter: 2800 errD_x: 0.02 errD_z: 0.05 errG: 3.39
# Epoch:1 Iter: 2900 errD_x: 0.13 errD_z: 0.04 errG: 3.83
# Epoch:1 Iter: 3000 errD_x: 0.08 errD_z: 0.05 errG: 3.28
# Epoch:1 Iter: 3100 errD_x: 0.05 errD_z: 0.05 errG: 3.34
# Epoch:1 Iter: 3200 errD_x: 0.06 errD_z: 0.03 errG: 4.18
# Epoch:1 Iter: 3300 errD_x: 0.01 errD_z: 0.07 errG: 3.08
# Epoch:1 Iter: 3400 errD_x: 0.04 errD_z: 0.03 errG: 4.10
# Epoch:1 Iter: 3500 errD_x: 0.03 errD_z: 0.08 errG: 3.03
# Epoch:1 Iter: 3600 errD_x: 0.10 errD_z: 0.05 errG: 3.28
# Epoch:1 Iter: 3700 errD_x: 0.08 errD_z: 0.14 errG: 2.23
# Epoch:2 Iter: 100 errD_x: 0.33 errD_z: 0.09 errG: 2.25
# Epoch:2 Iter: 200 errD_x: 0.46 errD_z: 0.11 errG: 2.81
# Epoch:2 Iter: 300 errD_x: 0.09 errD_z: 0.42 errG: 1.05
# Epoch:2 Iter: 400 errD_x: 0.17 errD_z: 0.20 errG: 2.21
# Epoch:2 Iter: 500 errD_x: 0.12 errD_z: 0.11 errG: 2.86
# Epoch:2 Iter: 600 errD_x: 0.09 errD_z: 0.29 errG: 1.97
# Epoch:2 Iter: 700 errD_x: 0.27 errD_z: 0.03 errG: 3.47
# Epoch:2 Iter: 800 errD_x: 0.04 errD_z: 0.17 errG: 2.20
# Epoch:2 Iter: 900 errD_x: 0.03 errD_z: 0.19 errG: 2.28
# Epoch:2 Iter: 1000 errD_x: 0.09 errD_z: 0.04 errG: 3.56
# Epoch:2 Iter: 1100 errD_x: 0.16 errD_z: 0.24 errG: 2.42
# Epoch:2 Iter: 1200 errD_x: 0.02 errD_z: 0.35 errG: 2.08
# Epoch:2 Iter: 1300 errD_x: 0.07 errD_z: 0.07 errG: 3.03
# Epoch:2 Iter: 1400 errD_x: 0.10 errD_z: 0.11 errG: 3.51
# Epoch:2 Iter: 1500 errD_x: 0.05 errD_z: 0.16 errG: 2.49
# Epoch:2 Iter: 1600 errD_x: 0.05 errD_z: 0.07 errG: 2.51
# Epoch:2 Iter: 1700 errD_x: 0.10 errD_z: 0.12 errG: 2.11
# Epoch:2 Iter: 1800 errD_x: 0.11 errD_z: 0.04 errG: 3.17
# Epoch:2 Iter: 1900 errD_x: 0.14 errD_z: 0.07 errG: 3.03
# Epoch:2 Iter: 2000 errD_x: 0.04 errD_z: 0.06 errG: 2.80
# Epoch:2 Iter: 2100 errD_x: 0.16 errD_z: 0.16 errG: 3.03
# Epoch:2 Iter: 2200 errD_x: 0.22 errD_z: 0.07 errG: 3.16
# Epoch:2 Iter: 2300 errD_x: 0.46 errD_z: 0.06 errG: 3.07
# Epoch:2 Iter: 2400 errD_x: 0.04 errD_z: 0.09 errG: 3.49
# Epoch:2 Iter: 2500 errD_x: 0.28 errD_z: 0.17 errG: 2.90
# Epoch:2 Iter: 2600 errD_x: 0.41 errD_z: 0.17 errG: 1.89
# Epoch:2 Iter: 2700 errD_x: 0.98 errD_z: 0.19 errG: 2.10
# Epoch:2 Iter: 2800 errD_x: 0.45 errD_z: 0.13 errG: 2.90
# Epoch:2 Iter: 2900 errD_x: 0.22 errD_z: 0.46 errG: 1.85
# Epoch:2 Iter: 3000 errD_x: 0.03 errD_z: 0.37 errG: 2.01
# Epoch:2 Iter: 3100 errD_x: 0.41 errD_z: 0.22 errG: 2.76
# Epoch:2 Iter: 3200 errD_x: 0.13 errD_z: 0.12 errG: 2.55
# Epoch:2 Iter: 3300 errD_x: 0.12 errD_z: 0.25 errG: 2.30
# Epoch:2 Iter: 3400 errD_x: 0.18 errD_z: 0.41 errG: 2.23
# Epoch:2 Iter: 3500 errD_x: 0.12 errD_z: 0.02 errG: 4.43
# Epoch:2 Iter: 3600 errD_x: 0.07 errD_z: 0.09 errG: 2.81
# Epoch:2 Iter: 3700 errD_x: 0.41 errD_z: 0.10 errG: 2.44
# Epoch:3 Iter: 100 errD_x: 0.32 errD_z: 0.06 errG: 3.16
# Epoch:3 Iter: 200 errD_x: 0.12 errD_z: 0.08 errG: 3.43
# Epoch:3 Iter: 300 errD_x: 0.32 errD_z: 0.11 errG: 2.62
# Epoch:3 Iter: 400 errD_x: 0.15 errD_z: 0.06 errG: 3.29
# Epoch:3 Iter: 500 errD_x: 0.07 errD_z: 0.23 errG: 2.12
# Epoch:3 Iter: 600 errD_x: 0.31 errD_z: 0.07 errG: 3.29
# Epoch:3 Iter: 700 errD_x: 0.17 errD_z: 0.53 errG: 1.30
# Epoch:3 Iter: 800 errD_x: 0.16 errD_z: 0.09 errG: 2.69
# Epoch:3 Iter: 900 errD_x: 0.10 errD_z: 0.37 errG: 1.72
# Epoch:3 Iter: 1000 errD_x: 0.12 errD_z: 0.41 errG: 1.12
# Epoch:3 Iter: 1100 errD_x: 0.18 errD_z: 0.10 errG: 1.84
# Epoch:3 Iter: 1200 errD_x: 0.34 errD_z: 0.18 errG: 2.30
# Epoch:3 Iter: 1300 errD_x: 0.32 errD_z: 0.19 errG: 2.30
# Epoch:3 Iter: 1400 errD_x: 0.11 errD_z: 0.53 errG: 1.38
# Epoch:3 Iter: 1500 errD_x: 0.28 errD_z: 0.15 errG: 2.47
# Epoch:3 Iter: 1600 errD_x: 0.35 errD_z: 0.06 errG: 3.36
# Epoch:3 Iter: 1700 errD_x: 0.05 errD_z: 0.22 errG: 2.33
# Epoch:3 Iter: 1800 errD_x: 0.08 errD_z: 0.14 errG: 2.81
# Epoch:3 Iter: 1900 errD_x: 0.19 errD_z: 0.10 errG: 2.79
# Epoch:3 Iter: 2000 errD_x: 0.26 errD_z: 0.04 errG: 3.24
# Epoch:3 Iter: 2100 errD_x: 0.19 errD_z: 0.13 errG: 2.72
# Epoch:3 Iter: 2200 errD_x: 0.08 errD_z: 0.12 errG: 3.05
# Epoch:3 Iter: 2300 errD_x: 0.21 errD_z: 0.25 errG: 1.99
# Epoch:3 Iter: 2400 errD_x: 0.54 errD_z: 0.14 errG: 2.32
# Epoch:3 Iter: 2500 errD_x: 0.69 errD_z: 0.12 errG: 2.00
# Epoch:3 Iter: 2600 errD_x: 0.33 errD_z: 0.19 errG: 2.33
# Epoch:3 Iter: 2700 errD_x: 0.37 errD_z: 0.17 errG: 2.09
# Epoch:3 Iter: 2800 errD_x: 0.28 errD_z: 0.05 errG: 3.39
# Epoch:3 Iter: 2900 errD_x: 0.94 errD_z: 0.19 errG: 1.83
# Epoch:3 Iter: 3000 errD_x: 0.25 errD_z: 0.21 errG: 2.60
# Epoch:3 Iter: 3100 errD_x: 0.34 errD_z: 0.21 errG: 1.86
# Epoch:3 Iter: 3200 errD_x: 0.34 errD_z: 0.21 errG: 1.61
# Epoch:3 Iter: 3300 errD_x: 0.31 errD_z: 0.13 errG: 2.68
# Epoch:3 Iter: 3400 errD_x: 0.14 errD_z: 0.13 errG: 2.53
# Epoch:3 Iter: 3500 errD_x: 0.43 errD_z: 0.28 errG: 2.26
# Epoch:3 Iter: 3600 errD_x: 0.22 errD_z: 0.20 errG: 1.91
# Epoch:3 Iter: 3700 errD_x: 0.40 errD_z: 0.13 errG: 2.32
# Epoch:4 Iter: 100 errD_x: 0.30 errD_z: 0.21 errG: 2.14
# Epoch:4 Iter: 200 errD_x: 0.28 errD_z: 0.09 errG: 2.29
# Epoch:4 Iter: 300 errD_x: 0.21 errD_z: 0.15 errG: 2.34
# Epoch:4 Iter: 400 errD_x: 0.29 errD_z: 0.24 errG: 2.12
# Epoch:4 Iter: 500 errD_x: 0.40 errD_z: 0.21 errG: 2.69
# Epoch:4 Iter: 600 errD_x: 0.34 errD_z: 0.37 errG: 2.03
# Epoch:4 Iter: 700 errD_x: 0.19 errD_z: 0.28 errG: 2.23
# Epoch:4 Iter: 800 errD_x: 0.41 errD_z: 0.31 errG: 2.49
# Epoch:4 Iter: 900 errD_x: 0.19 errD_z: 0.26 errG: 2.08
# Epoch:4 Iter: 1000 errD_x: 0.16 errD_z: 0.18 errG: 2.19
# Epoch:4 Iter: 1100 errD_x: 0.17 errD_z: 0.72 errG: 1.45
# Epoch:4 Iter: 1200 errD_x: 0.13 errD_z: 0.66 errG: 1.57
# Epoch:4 Iter: 1300 errD_x: 0.05 errD_z: 0.25 errG: 2.00
# Epoch:4 Iter: 1400 errD_x: 0.43 errD_z: 0.11 errG: 2.41
# Epoch:4 Iter: 1500 errD_x: 0.13 errD_z: 0.30 errG: 1.60
# Epoch:4 Iter: 1600 errD_x: 0.44 errD_z: 0.14 errG: 2.42
# Epoch:4 Iter: 1700 errD_x: 0.60 errD_z: 0.31 errG: 1.47
# Epoch:4 Iter: 1800 errD_x: 0.37 errD_z: 0.10 errG: 2.83
# Epoch:4 Iter: 1900 errD_x: 0.85 errD_z: 0.18 errG: 2.11
# Epoch:4 Iter: 2000 errD_x: 0.26 errD_z: 0.32 errG: 1.57
# Epoch:4 Iter: 2100 errD_x: 0.77 errD_z: 0.33 errG: 1.73
# Epoch:4 Iter: 2200 errD_x: 0.19 errD_z: 0.14 errG: 2.72
# Epoch:4 Iter: 2300 errD_x: 0.03 errD_z: 0.24 errG: 2.22
# Epoch:4 Iter: 2400 errD_x: 0.10 errD_z: 0.09 errG: 2.91
# Epoch:4 Iter: 2500 errD_x: 0.40 errD_z: 0.13 errG: 2.42
# Epoch:4 Iter: 2600 errD_x: 0.19 errD_z: 0.16 errG: 2.61
# Epoch:4 Iter: 2700 errD_x: 0.22 errD_z: 0.24 errG: 2.27
# Epoch:4 Iter: 2800 errD_x: 0.32 errD_z: 0.14 errG: 2.53
# Epoch:4 Iter: 2900 errD_x: 0.18 errD_z: 0.39 errG: 1.55
# Epoch:4 Iter: 3000 errD_x: 0.08 errD_z: 0.14 errG: 2.12
# Epoch:4 Iter: 3100 errD_x: 0.19 errD_z: 0.31 errG: 1.74
# Epoch:4 Iter: 3200 errD_x: 0.38 errD_z: 0.28 errG: 1.43
# Epoch:4 Iter: 3300 errD_x: 0.24 errD_z: 0.17 errG: 2.33
# Epoch:4 Iter: 3400 errD_x: 0.10 errD_z: 0.25 errG: 2.20
# Epoch:4 Iter: 3500 errD_x: 0.04 errD_z: 0.22 errG: 2.13
# Epoch:4 Iter: 3600 errD_x: 0.32 errD_z: 0.24 errG: 2.20
# Epoch:4 Iter: 3700 errD_x: 0.17 errD_z: 0.28 errG: 1.73
# Epoch:5 Iter: 100 errD_x: 0.14 errD_z: 0.21 errG: 2.80
# Epoch:5 Iter: 200 errD_x: 0.38 errD_z: 0.17 errG: 2.50
# Epoch:5 Iter: 300 errD_x: 0.12 errD_z: 0.28 errG: 1.72
# Epoch:5 Iter: 400 errD_x: 0.18 errD_z: 0.18 errG: 1.97
# Epoch:5 Iter: 500 errD_x: 0.40 errD_z: 0.34 errG: 1.82
# Epoch:5 Iter: 600 errD_x: 0.28 errD_z: 0.25 errG: 2.00
# Epoch:5 Iter: 700 errD_x: 0.03 errD_z: 0.25 errG: 2.66
# Epoch:5 Iter: 800 errD_x: 0.11 errD_z: 0.58 errG: 1.56
# Epoch:5 Iter: 900 errD_x: 0.98 errD_z: 0.08 errG: 2.88
# Epoch:5 Iter: 1000 errD_x: 0.44 errD_z: 0.36 errG: 1.83
# Epoch:5 Iter: 1100 errD_x: 0.30 errD_z: 0.34 errG: 1.93
# Epoch:5 Iter: 1200 errD_x: 0.24 errD_z: 0.43 errG: 1.47
# Epoch:5 Iter: 1300 errD_x: 0.16 errD_z: 0.40 errG: 1.56
# Epoch:5 Iter: 1400 errD_x: 0.38 errD_z: 0.25 errG: 3.07
# Epoch:5 Iter: 1500 errD_x: 0.62 errD_z: 0.24 errG: 1.98
# Epoch:5 Iter: 1600 errD_x: 0.08 errD_z: 0.35 errG: 2.31
# Epoch:5 Iter: 1700 errD_x: 0.06 errD_z: 0.32 errG: 1.86
# Epoch:5 Iter: 1800 errD_x: 0.40 errD_z: 0.23 errG: 2.09
# Epoch:5 Iter: 1900 errD_x: 0.42 errD_z: 0.45 errG: 1.89
# Epoch:5 Iter: 2000 errD_x: 0.11 errD_z: 0.32 errG: 1.88
# Epoch:5 Iter: 2100 errD_x: 0.46 errD_z: 0.23 errG: 1.89
# Epoch:5 Iter: 2200 errD_x: 0.09 errD_z: 0.24 errG: 2.36
# Epoch:5 Iter: 2300 errD_x: 0.33 errD_z: 0.21 errG: 2.03
# Epoch:5 Iter: 2400 errD_x: 0.51 errD_z: 0.12 errG: 2.16
# Epoch:5 Iter: 2500 errD_x: 1.03 errD_z: 0.06 errG: 3.16
# Epoch:5 Iter: 2600 errD_x: 0.10 errD_z: 0.11 errG: 3.81
# Epoch:5 Iter: 2700 errD_x: 0.27 errD_z: 0.19 errG: 1.76
# Epoch:5 Iter: 2800 errD_x: 0.42 errD_z: 0.28 errG: 1.60
# Epoch:5 Iter: 2900 errD_x: 0.22 errD_z: 0.08 errG: 2.49
# Epoch:5 Iter: 3000 errD_x: 0.50 errD_z: 0.23 errG: 2.16
# Epoch:5 Iter: 3100 errD_x: 0.25 errD_z: 0.12 errG: 2.77
# Epoch:5 Iter: 3200 errD_x: 0.31 errD_z: 0.29 errG: 1.81
# Epoch:5 Iter: 3300 errD_x: 0.40 errD_z: 0.18 errG: 1.45
# Epoch:5 Iter: 3400 errD_x: 0.03 errD_z: 0.22 errG: 2.29
# Epoch:5 Iter: 3500 errD_x: 0.25 errD_z: 0.48 errG: 1.80
# Epoch:5 Iter: 3600 errD_x: 0.59 errD_z: 0.12 errG: 2.82
# Epoch:5 Iter: 3700 errD_x: 0.47 errD_z: 0.29 errG: 1.71
# Epoch:6 Iter: 100 errD_x: 0.29 errD_z: 0.21 errG: 2.26
# Epoch:6 Iter: 200 errD_x: 0.26 errD_z: 0.18 errG: 2.19
# Epoch:6 Iter: 300 errD_x: 0.64 errD_z: 0.28 errG: 2.12
# Epoch:6 Iter: 400 errD_x: 0.13 errD_z: 0.14 errG: 2.48
# Epoch:6 Iter: 500 errD_x: 0.25 errD_z: 0.19 errG: 2.14
# Epoch:6 Iter: 600 errD_x: 0.50 errD_z: 0.10 errG: 2.52
# Epoch:6 Iter: 700 errD_x: 0.42 errD_z: 0.07 errG: 3.03
# Epoch:6 Iter: 800 errD_x: 0.23 errD_z: 0.10 errG: 3.54
# Epoch:6 Iter: 900 errD_x: 0.02 errD_z: 0.37 errG: 1.63
# Epoch:6 Iter: 1000 errD_x: 0.25 errD_z: 0.16 errG: 2.45
# Epoch:6 Iter: 1100 errD_x: 0.25 errD_z: 0.13 errG: 2.51
# Epoch:6 Iter: 1200 errD_x: 0.39 errD_z: 0.06 errG: 3.50
# Epoch:6 Iter: 1300 errD_x: 0.22 errD_z: 0.09 errG: 2.78
# Epoch:6 Iter: 1400 errD_x: 0.31 errD_z: 0.10 errG: 2.36
# Epoch:6 Iter: 1500 errD_x: 0.55 errD_z: 0.08 errG: 3.07
# Epoch:6 Iter: 1600 errD_x: 0.77 errD_z: 0.24 errG: 1.84
# Epoch:6 Iter: 1700 errD_x: 0.64 errD_z: 0.09 errG: 2.90
# Epoch:6 Iter: 1800 errD_x: 0.02 errD_z: 0.15 errG: 2.75
# Epoch:6 Iter: 1900 errD_x: 0.21 errD_z: 0.15 errG: 2.87
# Epoch:6 Iter: 2000 errD_x: 0.55 errD_z: 0.15 errG: 2.64
# Epoch:6 Iter: 2100 errD_x: 0.59 errD_z: 0.08 errG: 2.88
# Epoch:6 Iter: 2200 errD_x: 0.14 errD_z: 0.17 errG: 2.64
# Epoch:6 Iter: 2300 errD_x: 0.20 errD_z: 0.12 errG: 2.36
# Epoch:6 Iter: 2400 errD_x: 0.86 errD_z: 0.03 errG: 3.50
# Epoch:6 Iter: 2500 errD_x: 0.60 errD_z: 0.18 errG: 1.97
# Epoch:6 Iter: 2600 errD_x: 0.56 errD_z: 0.15 errG: 2.15
# Epoch:6 Iter: 2700 errD_x: 0.21 errD_z: 0.22 errG: 2.74
# Epoch:6 Iter: 2800 errD_x: 0.37 errD_z: 0.21 errG: 2.54
# Epoch:6 Iter: 2900 errD_x: 0.07 errD_z: 0.31 errG: 2.03
# Epoch:6 Iter: 3000 errD_x: 0.50 errD_z: 0.18 errG: 1.95
# Epoch:6 Iter: 3100 errD_x: 0.28 errD_z: 0.14 errG: 2.61
# Epoch:6 Iter: 3200 errD_x: 0.52 errD_z: 0.19 errG: 2.88
# Epoch:6 Iter: 3300 errD_x: 0.74 errD_z: 0.11 errG: 2.81
# Epoch:6 Iter: 3400 errD_x: 0.18 errD_z: 0.19 errG: 1.87
# Epoch:6 Iter: 3500 errD_x: 0.30 errD_z: 0.32 errG: 1.87
# Epoch:6 Iter: 3600 errD_x: 0.19 errD_z: 0.08 errG: 2.69
# Epoch:6 Iter: 3700 errD_x: 0.34 errD_z: 0.12 errG: 2.52
# Epoch:7 Iter: 100 errD_x: 0.26 errD_z: 0.24 errG: 2.25
# Epoch:7 Iter: 200 errD_x: 0.78 errD_z: 0.12 errG: 3.20
# Epoch:7 Iter: 300 errD_x: 0.22 errD_z: 0.09 errG: 2.80
# Epoch:7 Iter: 400 errD_x: 0.20 errD_z: 0.14 errG: 2.31
# Epoch:7 Iter: 500 errD_x: 1.03 errD_z: 0.20 errG: 1.82
# Epoch:7 Iter: 600 errD_x: 0.26 errD_z: 0.07 errG: 3.65
# Epoch:7 Iter: 700 errD_x: 0.28 errD_z: 0.37 errG: 1.35
# Epoch:7 Iter: 800 errD_x: 0.34 errD_z: 0.10 errG: 2.85
# Epoch:7 Iter: 900 errD_x: 0.01 errD_z: 0.29 errG: 2.32
# Epoch:7 Iter: 1000 errD_x: 0.14 errD_z: 0.29 errG: 1.94
# Epoch:7 Iter: 1100 errD_x: 0.48 errD_z: 0.24 errG: 1.76
# Epoch:7 Iter: 1200 errD_x: 0.70 errD_z: 0.29 errG: 1.79
# Epoch:7 Iter: 1300 errD_x: 0.80 errD_z: 0.26 errG: 2.30
# Epoch:7 Iter: 1400 errD_x: 0.27 errD_z: 0.39 errG: 2.18
# Epoch:7 Iter: 1500 errD_x: 0.30 errD_z: 0.15 errG: 2.44
# Epoch:7 Iter: 1600 errD_x: 0.32 errD_z: 0.12 errG: 2.54
# Epoch:7 Iter: 1700 errD_x: 0.60 errD_z: 0.18 errG: 2.70
# Epoch:7 Iter: 1800 errD_x: 0.16 errD_z: 0.12 errG: 3.34
# Epoch:7 Iter: 1900 errD_x: 0.36 errD_z: 0.41 errG: 2.22
# Epoch:7 Iter: 2000 errD_x: 0.58 errD_z: 0.17 errG: 2.25
# Epoch:7 Iter: 2100 errD_x: 0.20 errD_z: 0.19 errG: 2.12
# Epoch:7 Iter: 2200 errD_x: 0.35 errD_z: 0.21 errG: 2.06
# Epoch:7 Iter: 2300 errD_x: 0.83 errD_z: 0.18 errG: 2.28
# Epoch:7 Iter: 2400 errD_x: 0.15 errD_z: 0.32 errG: 1.34
# Epoch:7 Iter: 2500 errD_x: 0.05 errD_z: 0.30 errG: 1.88
# Epoch:7 Iter: 2600 errD_x: 0.39 errD_z: 0.11 errG: 2.84
# Epoch:7 Iter: 2700 errD_x: 0.65 errD_z: 0.16 errG: 1.84
# Epoch:7 Iter: 2800 errD_x: 0.08 errD_z: 0.54 errG: 1.25
# Epoch:7 Iter: 2900 errD_x: 1.02 errD_z: 0.17 errG: 2.62
# Epoch:7 Iter: 3000 errD_x: 0.33 errD_z: 0.35 errG: 1.91
# Epoch:7 Iter: 3100 errD_x: 1.16 errD_z: 0.41 errG: 1.78
# Epoch:7 Iter: 3200 errD_x: 0.13 errD_z: 0.44 errG: 1.32
# Epoch:7 Iter: 3300 errD_x: 0.36 errD_z: 0.19 errG: 2.33
# Epoch:7 Iter: 3400 errD_x: 0.47 errD_z: 0.20 errG: 2.91
# Epoch:7 Iter: 3500 errD_x: 0.60 errD_z: 0.27 errG: 1.42
# Epoch:7 Iter: 3600 errD_x: 0.32 errD_z: 0.23 errG: 3.06
# Epoch:7 Iter: 3700 errD_x: 0.08 errD_z: 0.39 errG: 1.88
# Epoch:8 Iter: 100 errD_x: 0.94 errD_z: 0.31 errG: 1.87
# Epoch:8 Iter: 200 errD_x: 0.61 errD_z: 0.23 errG: 2.31
# Epoch:8 Iter: 300 errD_x: 0.25 errD_z: 0.30 errG: 2.24
# Epoch:8 Iter: 400 errD_x: 0.05 errD_z: 0.13 errG: 2.43
# Epoch:8 Iter: 500 errD_x: 0.28 errD_z: 0.26 errG: 1.98
# Epoch:8 Iter: 600 errD_x: 0.45 errD_z: 0.15 errG: 2.54
# Epoch:8 Iter: 700 errD_x: 0.31 errD_z: 0.36 errG: 2.15
# Epoch:8 Iter: 800 errD_x: 0.29 errD_z: 0.12 errG: 2.70
# Epoch:8 Iter: 900 errD_x: 0.20 errD_z: 0.18 errG: 2.04
# Epoch:8 Iter: 1000 errD_x: 0.64 errD_z: 0.29 errG: 2.25
# Epoch:8 Iter: 1100 errD_x: 0.37 errD_z: 0.25 errG: 2.03
# Epoch:8 Iter: 1200 errD_x: 0.60 errD_z: 0.10 errG: 3.19
# Epoch:8 Iter: 1300 errD_x: 0.35 errD_z: 0.50 errG: 1.83
# Epoch:8 Iter: 1400 errD_x: 0.42 errD_z: 0.22 errG: 2.13
# Epoch:8 Iter: 1500 errD_x: 0.52 errD_z: 0.18 errG: 2.09
# Epoch:8 Iter: 1600 errD_x: 0.08 errD_z: 0.53 errG: 1.61
# Epoch:8 Iter: 1700 errD_x: 0.22 errD_z: 0.53 errG: 1.07
# Epoch:8 Iter: 1800 errD_x: 0.27 errD_z: 0.18 errG: 2.40
# Epoch:8 Iter: 1900 errD_x: 0.05 errD_z: 0.38 errG: 2.34
# Epoch:8 Iter: 2000 errD_x: 0.41 errD_z: 0.37 errG: 1.57
# Epoch:8 Iter: 2100 errD_x: 0.44 errD_z: 0.07 errG: 2.97
# Epoch:8 Iter: 2200 errD_x: 0.32 errD_z: 0.06 errG: 3.71
# Epoch:8 Iter: 2300 errD_x: 0.53 errD_z: 0.11 errG: 3.42
# Epoch:8 Iter: 2400 errD_x: 0.09 errD_z: 0.38 errG: 1.85
# Epoch:8 Iter: 2500 errD_x: 0.30 errD_z: 0.14 errG: 2.25
# Epoch:8 Iter: 2600 errD_x: 0.83 errD_z: 0.22 errG: 2.02
# Epoch:8 Iter: 2700 errD_x: 0.50 errD_z: 0.12 errG: 2.47
# Epoch:8 Iter: 2800 errD_x: 0.29 errD_z: 0.26 errG: 2.68
# Epoch:8 Iter: 2900 errD_x: 0.07 errD_z: 0.23 errG: 2.19
# Epoch:8 Iter: 3000 errD_x: 0.41 errD_z: 0.29 errG: 1.80
# Epoch:8 Iter: 3100 errD_x: 0.36 errD_z: 0.21 errG: 2.31
# Epoch:8 Iter: 3200 errD_x: 0.21 errD_z: 0.13 errG: 2.75
# Epoch:8 Iter: 3300 errD_x: 0.27 errD_z: 0.15 errG: 3.54
# Epoch:8 Iter: 3400 errD_x: 0.33 errD_z: 0.35 errG: 1.95
# Epoch:8 Iter: 3500 errD_x: 0.31 errD_z: 0.15 errG: 2.73
# Epoch:8 Iter: 3600 errD_x: 0.11 errD_z: 0.15 errG: 3.23
# Epoch:8 Iter: 3700 errD_x: 0.47 errD_z: 0.17 errG: 2.25
# Epoch:9 Iter: 100 errD_x: 0.10 errD_z: 0.32 errG: 2.12
# Epoch:9 Iter: 200 errD_x: 0.40 errD_z: 0.86 errG: 1.04
# Epoch:9 Iter: 300 errD_x: 0.39 errD_z: 0.30 errG: 2.56
# Epoch:9 Iter: 400 errD_x: 0.40 errD_z: 0.31 errG: 2.18
# Epoch:9 Iter: 500 errD_x: 0.22 errD_z: 0.49 errG: 1.66
# Epoch:9 Iter: 600 errD_x: 0.10 errD_z: 0.36 errG: 2.04
# Epoch:9 Iter: 700 errD_x: 0.47 errD_z: 0.08 errG: 2.75
# Epoch:9 Iter: 800 errD_x: 0.06 errD_z: 0.19 errG: 3.20
# Epoch:9 Iter: 900 errD_x: 0.21 errD_z: 0.15 errG: 2.61
# Epoch:9 Iter: 1000 errD_x: 0.24 errD_z: 0.43 errG: 1.66
# Epoch:9 Iter: 1100 errD_x: 0.59 errD_z: 0.39 errG: 1.72
# Epoch:9 Iter: 1200 errD_x: 0.22 errD_z: 0.16 errG: 2.54
# Epoch:9 Iter: 1300 errD_x: 0.18 errD_z: 0.53 errG: 1.27
# Epoch:9 Iter: 1400 errD_x: 0.58 errD_z: 0.45 errG: 2.18
# Epoch:9 Iter: 1500 errD_x: 0.03 errD_z: 0.53 errG: 1.66
# Epoch:9 Iter: 1600 errD_x: 0.48 errD_z: 0.13 errG: 2.21
# Epoch:9 Iter: 1700 errD_x: 0.49 errD_z: 0.11 errG: 2.87
# Epoch:9 Iter: 1800 errD_x: 0.05 errD_z: 0.12 errG: 2.76
# Epoch:9 Iter: 1900 errD_x: 0.11 errD_z: 0.22 errG: 2.02
# Epoch:9 Iter: 2000 errD_x: 0.52 errD_z: 0.16 errG: 2.55
# Epoch:9 Iter: 2100 errD_x: 0.18 errD_z: 0.13 errG: 2.45
# Epoch:9 Iter: 2200 errD_x: 0.32 errD_z: 0.07 errG: 3.20
# Epoch:9 Iter: 2300 errD_x: 0.81 errD_z: 0.23 errG: 2.78
# Epoch:9 Iter: 2400 errD_x: 0.21 errD_z: 0.18 errG: 2.33
# Epoch:9 Iter: 2500 errD_x: 0.23 errD_z: 0.37 errG: 1.37
# Epoch:9 Iter: 2600 errD_x: 0.58 errD_z: 0.12 errG: 2.95
# Epoch:9 Iter: 2700 errD_x: 0.14 errD_z: 0.22 errG: 2.45
# Epoch:9 Iter: 2800 errD_x: 0.41 errD_z: 0.29 errG: 1.99
# Epoch:9 Iter: 2900 errD_x: 0.28 errD_z: 0.12 errG: 2.59
# Epoch:9 Iter: 3000 errD_x: 0.46 errD_z: 0.32 errG: 1.54
# Epoch:9 Iter: 3100 errD_x: 0.51 errD_z: 0.24 errG: 2.43
# Epoch:9 Iter: 3200 errD_x: 0.51 errD_z: 0.11 errG: 2.52
# Epoch:9 Iter: 3300 errD_x: 0.23 errD_z: 0.15 errG: 2.45
# Epoch:9 Iter: 3400 errD_x: 0.20 errD_z: 0.22 errG: 1.81
# Epoch:9 Iter: 3500 errD_x: 0.23 errD_z: 0.24 errG: 1.75
# Epoch:9 Iter: 3600 errD_x: 0.22 errD_z: 0.25 errG: 2.28
# Epoch:9 Iter: 3700 errD_x: 0.67 errD_z: 0.14 errG: 1.87
# Epoch:10 Iter: 100 errD_x: 0.09 errD_z: 0.08 errG: 2.91
# Epoch:10 Iter: 200 errD_x: 0.14 errD_z: 0.43 errG: 1.44
# Epoch:10 Iter: 300 errD_x: 0.49 errD_z: 0.32 errG: 1.63
# Epoch:10 Iter: 400 errD_x: 0.32 errD_z: 0.26 errG: 1.87
# Epoch:10 Iter: 500 errD_x: 0.40 errD_z: 0.13 errG: 2.54
# Epoch:10 Iter: 600 errD_x: 0.63 errD_z: 0.28 errG: 1.40
# Epoch:10 Iter: 700 errD_x: 0.17 errD_z: 0.18 errG: 2.71
# Epoch:10 Iter: 800 errD_x: 0.25 errD_z: 0.41 errG: 1.87
# Epoch:10 Iter: 900 errD_x: 0.25 errD_z: 0.34 errG: 1.77
# Epoch:10 Iter: 1000 errD_x: 0.79 errD_z: 0.20 errG: 1.94
# Epoch:10 Iter: 1100 errD_x: 0.61 errD_z: 0.13 errG: 2.01
# Epoch:10 Iter: 1200 errD_x: 0.30 errD_z: 0.44 errG: 1.49
# Epoch:10 Iter: 1300 errD_x: 0.43 errD_z: 0.12 errG: 2.81
# Epoch:10 Iter: 1400 errD_x: 1.18 errD_z: 0.12 errG: 2.09
# Epoch:10 Iter: 1500 errD_x: 0.35 errD_z: 0.18 errG: 2.26
# Epoch:10 Iter: 1600 errD_x: 0.50 errD_z: 0.26 errG: 1.80
# Epoch:10 Iter: 1700 errD_x: 0.60 errD_z: 0.11 errG: 2.27
# Epoch:10 Iter: 1800 errD_x: 0.39 errD_z: 0.45 errG: 1.42
# Epoch:10 Iter: 1900 errD_x: 0.11 errD_z: 0.25 errG: 1.56
# Epoch:10 Iter: 2000 errD_x: 0.58 errD_z: 0.38 errG: 1.90
# Epoch:10 Iter: 2100 errD_x: 0.30 errD_z: 0.45 errG: 1.57
# Epoch:10 Iter: 2200 errD_x: 0.43 errD_z: 0.17 errG: 2.00
# Epoch:10 Iter: 2300 errD_x: 0.31 errD_z: 0.22 errG: 2.45
# Epoch:10 Iter: 2400 errD_x: 0.27 errD_z: 0.59 errG: 1.68
# Epoch:10 Iter: 2500 errD_x: 0.16 errD_z: 0.18 errG: 2.43
# Epoch:10 Iter: 2600 errD_x: 0.25 errD_z: 0.39 errG: 1.37
# Epoch:10 Iter: 2700 errD_x: 0.41 errD_z: 0.32 errG: 1.96
# Epoch:10 Iter: 2800 errD_x: 0.13 errD_z: 0.31 errG: 1.80
# Epoch:10 Iter: 2900 errD_x: 1.01 errD_z: 0.11 errG: 2.24
# Epoch:10 Iter: 3000 errD_x: 0.29 errD_z: 0.53 errG: 1.56
# Epoch:10 Iter: 3100 errD_x: 0.37 errD_z: 0.20 errG: 2.26
# Epoch:10 Iter: 3200 errD_x: 0.23 errD_z: 0.28 errG: 2.17
# Epoch:10 Iter: 3300 errD_x: 0.62 errD_z: 0.24 errG: 2.28
# Epoch:10 Iter: 3400 errD_x: 0.45 errD_z: 0.49 errG: 1.45
# Epoch:10 Iter: 3500 errD_x: 0.12 errD_z: 0.22 errG: 2.67
# Epoch:10 Iter: 3600 errD_x: 0.26 errD_z: 0.16 errG: 2.31
# Epoch:10 Iter: 3700 errD_x: 0.69 errD_z: 0.26 errG: 1.95

# %%
noise.data.normal_(0, 1)
fake = generator(noise)

plt.figure(figsize=(6, 7))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(fake[i].detach().numpy().reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.axis('off')
